# %%
# !printf "1\n" | gmx editconf -f helix.pdb -princ -o helix_turned.pdb
# Out:
#                      :-) GROMACS - gmx editconf, 2024.1 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/hamajun/study/4_sem/inf/helices/test_unstable
# Command line:
#   gmx editconf -f helix.pdb -princ -o helix_turned.pdb
#
# Note that major changes are planned in future for editconf, to improve usability and utility.
# Read 300 atoms
# Volume: 0 nm^3, corresponds to roughly 0 electrons
# No velocities found
#     system size :  2.228  1.961  1.439 (nm)
#     center      :  0.363 -0.242 -0.139 (nm)
#     box vectors :  0.000  0.000  0.000 (nm)
#     box angles  :   0.00   0.00   0.00 (degrees)
#     box volume  :   0.00               (nm^3)
#
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
#          based on residue and atom names, since they could not be
#          definitively assigned from the information in your input
#          files. These guessed numbers might deviate from the mass
#          and radius of the atom type. Please check the output
#          files if necessary. Note, that this functionality may
#          be removed in a future GROMACS version. Please, consider
#          using another file format for your input.
#
#
# Select group for the determining the orientation
# Group     0 (         System) has   300 elements
# Group     1 (        Protein) has   300 elements
# Group     2 (      Protein-H) has    99 elements
# Group     3 (        C-alpha) has    12 elements
# Group     4 (       Backbone) has    36 elements
# Group     5 (      MainChain) has    48 elements
# Group     6 (   MainChain+Cb) has    59 elements
# Group     7 (    MainChain+H) has    57 elements
# Group     8 (      SideChain) has   243 elements
# Group     9 (    SideChain-H) has    51 elements
# Select a group: Selected 1: 'Protein'
# new system size :  2.265  1.635  1.408
# new center      :  0.285 -0.414 -0.154 (nm)
# new box vectors :  0.000  0.000  0.000 (nm)
# new box angles  :   0.00   0.00   0.00 (degrees)
# new box volume  :   0.00               (nm^3)
#
# WARNING: Empty diagonal for a 3-dimensional periodic box
# See the GROMACS manual for a description of the requirements that
# must be satisfied by descriptions of simulation cells.
#
# GROMACS reminds you: "With a Little Penknife" (Nick Cave)

# %%
# !gmx pdb2gmx -f helix_turned.pdb -o helix_processed.gro -water spce -ff "charmm27" -ignh
# Out:
#                      :-) GROMACS - gmx pdb2gmx, 2024.1 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/hamajun/study/4_sem/inf/helices/test_unstable
# Command line:
#   gmx pdb2gmx -f helix_turned.pdb -o helix_processed.gro -water spce -ff charmm27 -ignh
#
# Using the Charmm27 force field in directory charmm27.ff
#
# going to rename charmm27.ff/aminoacids.r2b
# Opening force field file /usr/local/gromacs/share/gromacs/top/charmm27.ff/aminoacids.r2b
#
# going to rename charmm27.ff/rna.r2b
# Opening force field file /usr/local/gromacs/share/gromacs/top/charmm27.ff/rna.r2b
# Reading helix_turned.pdb...
# Read 'Good gRace! Old Maple Actually Chews Slate', 99 atoms
#
# Analyzing pdb file
# Splitting chemical chains based on TER records or chain id changing.
#
# There are 1 chains and 0 blocks of water and 13 residues with 99 atoms
#
#   chain  #res #atoms
#
#   1 'X'    12     99
#
# there were 0 atoms with zero occupancy and 99 atoms with          occupancy unequal to one (out of 99 atoms). Check your pdb file.
# there were 0 atoms with zero occupancy and 99 atoms with          occupancy unequal to one (out of 99 atoms). Check your pdb file.
# Opening force field file /usr/local/gromacs/share/gromacs/top/charmm27.ff/atomtypes.atp
#
# Reading residue database... (Charmm27)
# Opening force field file /usr/local/gromacs/share/gromacs/top/charmm27.ff/aminoacids.rtp
# Opening force field file /usr/local/gromacs/share/gromacs/top/charmm27.ff/dna.rtp
# Opening force field file /usr/local/gromacs/share/gromacs/top/charmm27.ff/lipids.rtp
# Opening force field file /usr/local/gromacs/share/gromacs/top/charmm27.ff/rna.rtp
# Opening force field file /usr/local/gromacs/share/gromacs/top/charmm27.ff/aminoacids.hdb
# Opening force field file /usr/local/gromacs/share/gromacs/top/charmm27.ff/dna.hdb
# Opening force field file /usr/local/gromacs/share/gromacs/top/charmm27.ff/lipids.hdb
# Opening force field file /usr/local/gromacs/share/gromacs/top/charmm27.ff/rna.hdb
# Opening force field file /usr/local/gromacs/share/gromacs/top/charmm27.ff/aminoacids.n.tdb
# Opening force field file /usr/local/gromacs/share/gromacs/top/charmm27.ff/dna.n.tdb
# Opening force field file /usr/local/gromacs/share/gromacs/top/charmm27.ff/rna.n.tdb
# Opening force field file /usr/local/gromacs/share/gromacs/top/charmm27.ff/aminoacids.c.tdb
# Opening force field file /usr/local/gromacs/share/gromacs/top/charmm27.ff/dna.c.tdb
# Opening force field file /usr/local/gromacs/share/gromacs/top/charmm27.ff/rna.c.tdb
#
# Processing chain 1 'X' (99 atoms, 12 residues)
# Analysing hydrogen-bonding network for automated assignment of histidine
#  protonation. 20 donors and 20 acceptors were found.
# There are 13 hydrogen bonds
# Will use HISE for residue 1
#
# Identified residue HIS1 as a starting terminus.
#
# Identified residue ASP12 as a ending terminus.
# 9 out of 9 lines of specbond.dat converted successfully
# Special Atom Distance matrix:
#                     HIS1
#                     NE29
#     CYS9    SG75   1.187
# Start terminus HIS-1: NH3+
# End terminus ASP-12: COO-
# Opening force field file /usr/local/gromacs/share/gromacs/top/charmm27.ff/aminoacids.arn
# Opening force field file /usr/local/gromacs/share/gromacs/top/charmm27.ff/dna.arn
# Opening force field file /usr/local/gromacs/share/gromacs/top/charmm27.ff/rna.arn
#
# Checking for duplicate atoms....
#
# Generating any missing hydrogen atoms and/or adding termini.
#
# Now there are 12 residues with 186 atoms
#
# Making bonds...
#
# Number of bonds was 189, now 189
#
# Generating angles, dihedrals and pairs...
# Before cleaning: 489 pairs
# Before cleaning: 504 dihedrals
#
# Making cmap torsions...
#
# There are   10 cmap torsion pairs
#
# There are  504 dihedrals,   37 impropers,  339 angles
#            486 pairs,      189 bonds and     0 virtual sites
#
# Total mass 1429.510 a.m.u.
#
# Total charge -1.000 e
#
# Writing topology
#
# Writing coordinate file...
#
# 		--------- PLEASE NOTE ------------
#
# You have successfully generated a topology from: helix_turned.pdb.
#
# The Charmm27 force field and the spce water model are used.
#
# 		--------- ETON ESAELP ------------
#
# GROMACS reminds you: "If You See Me Getting High, Knock Me Down" (Red Hot Chili Peppers)

# %%
# !gmx editconf -f helix_processed.gro -o helix_newbox.gro -c -d 1.0 -bt dodecahedron
# Out:
#                      :-) GROMACS - gmx editconf, 2024.1 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/hamajun/study/4_sem/inf/helices/test_unstable
# Command line:
#   gmx editconf -f helix_processed.gro -o helix_newbox.gro -c -d 1.0 -bt dodecahedron
#
# Note that major changes are planned in future for editconf, to improve usability and utility.
# Read 186 atoms
# Volume: 5.19314 nm^3, corresponds to roughly 2300 electrons
# No velocities found
#     system size :  2.249  1.646  1.404 (nm)
#     diameter    :  2.379               (nm)
#     center      :  0.538 -0.407 -0.146 (nm)
#     box vectors :  2.248  1.645  1.404 (nm)
#     box angles  :  90.00  90.00  90.00 (degrees)
#     box volume  :   5.19               (nm^3)
#     shift       :  2.747  3.691  1.694 (nm)
# new center      :  3.284  3.284  1.548 (nm)
# new box vectors :  4.379  4.379  4.379 (nm)
# new box angles  :  60.00  60.00  90.00 (degrees)
# new box volume  :  59.39               (nm^3)
#
# GROMACS reminds you: "I wanted to make a clever chemistry joke, but the best ones Argon." (39.948)

# %%
# !gmx solvate -cp helix_newbox.gro -cs spc216.gro -o helix_solv.gro -p topol.top
# Out:
#                      :-) GROMACS - gmx solvate, 2024.1 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/hamajun/study/4_sem/inf/helices/test_unstable
# Command line:
#   gmx solvate -cp helix_newbox.gro -cs spc216.gro -o helix_solv.gro -p topol.top
#
# Reading solute configuration
# Reading solvent configuration
#
# Initialising inter-atomic distances...
#
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
#          based on residue and atom names, since they could not be
#          definitively assigned from the information in your input
#          files. These guessed numbers might deviate from the mass
#          and radius of the atom type. Please check the output
#          files if necessary. Note, that this functionality may
#          be removed in a future GROMACS version. Please, consider
#          using another file format for your input.
#
# NOTE: From version 5.0 gmx solvate uses the Van der Waals radii
# from the source below. This means the results may be different
# compared to previous GROMACS versions.
#
# ++++ PLEASE READ AND CITE THE FOLLOWING REFERENCE ++++
# A. Bondi
# van der Waals Volumes and Radii
# J. Phys. Chem. 68 (1964) pp. 441-451
# -------- -------- --- Thank You --- -------- --------
#
# Generating solvent configuration
# Will generate new solvent configuration of 3x3x2 boxes
# Solvent box contains 7467 atoms in 2489 residues
# Removed 1590 solvent atoms due to solvent-solvent overlap
# Removed 204 solvent atoms due to solute-solvent overlap
# Sorting configuration
# Found 1 molecule type:
#     SOL (   3 atoms):  1891 residues
# Generated solvent containing 5673 atoms in 1891 residues
# Writing generated configuration to helix_solv.gro
#
# Output configuration contains 5859 atoms in 1903 residues
# Volume                 :     59.3873 (nm^3)
# Density                :     994.867 (g/l)
# Number of solvent molecules:   1891
#
# Processing topology
# Adding line for 1891 solvent molecules with resname (SOL) to topology file (topol.top)
#
# Back Off! I just backed up topol.top to ./#topol.top.1#
#
# GROMACS reminds you: "The Universe is Somewhere In Here" (J.G.E.M. Fraaije)

# %%
# !gmx grompp -f ions.mdp -c helix_solv.gro -p topol.top -o ions.tpr
# Out:
#                       :-) GROMACS - gmx grompp, 2024.1 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/hamajun/study/4_sem/inf/helices/test_unstable
# Command line:
#   gmx grompp -f ions.mdp -c helix_solv.gro -p topol.top -o ions.tpr
#
# Ignoring obsolete mdp entry 'ns_type'
#
# NOTE 1 [file ions.mdp]:
#   With Verlet lists the optimal nstlist is >= 10, with GPUs >= 20. Note
#   that with the Verlet scheme, nstlist has no effect on the accuracy of
#   your simulation.
#
# Setting the LD random seed to 2063331231
#
# Generated 20503 of the 20503 non-bonded parameter combinations
# Generating 1-4 interactions: fudge = 1
#
# Generated 17396 of the 20503 1-4 parameter combinations
#
# Excluding 3 bonded neighbours molecule type 'Protein_chain_X'
#
# Excluding 2 bonded neighbours molecule type 'SOL'
#
# NOTE 2 [file topol.top, line 1836]:
#   System has non-zero total charge: -1.000000
#   Total charge should normally be an integer. See
#   https://manual.gromacs.org/current/user-guide/floating-point.html
#   for discussion on how close it should be to an integer.
#
#
#
# Analysing residue names:
# There are:    12    Protein residues
# There are:  1891      Water residues
# Analysing Protein...
# Number of degrees of freedom in T-Coupling group rest is 11901.00
# The integrator does not provide a ensemble temperature, there is no system ensemble temperature
#
# NOTE 3 [file ions.mdp]:
#   You are using a plain Coulomb cut-off, which might produce artifacts.
#   You might want to consider using PME electrostatics.
#
#
#
# This run will generate roughly 1 Mb of data
#
# There were 3 NOTEs
#
# GROMACS reminds you: "They Paint Their Faces So Differently From Ours" (Gogol Bordello)

# %%
# !printf "SOL" | gmx genion -s ions.tpr -o helix_solv_ions.gro -p topol.top -pname NA -nname CL -neutral
# Out:
#                       :-) GROMACS - gmx genion, 2024.1 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/hamajun/study/4_sem/inf/helices/test_unstable
# Command line:
#   gmx genion -s ions.tpr -o helix_solv_ions.gro -p topol.top -pname NA -nname CL -neutral
#
# Reading file ions.tpr, VERSION 2024.1 (single precision)
# Reading file ions.tpr, VERSION 2024.1 (single precision)
# Will try to add 1 NA ions and 0 CL ions.
# Select a continuous group of solvent molecules
# Group     0 (         System) has  5859 elements
# Group     1 (        Protein) has   186 elements
# Group     2 (      Protein-H) has   100 elements
# Group     3 (        C-alpha) has    12 elements
# Group     4 (       Backbone) has    36 elements
# Group     5 (      MainChain) has    47 elements
# Group     6 (   MainChain+Cb) has    58 elements
# Group     7 (    MainChain+H) has    59 elements
# Group     8 (      SideChain) has   127 elements
# Group     9 (    SideChain-H) has    53 elements
# Group    10 (    Prot-Masses) has   186 elements
# Group    11 (    non-Protein) has  5673 elements
# Group    12 (          Water) has  5673 elements
# Group    13 (            SOL) has  5673 elements
# Group    14 (      non-Water) has   186 elements
# Select a group: Selected 13: 'SOL'
# Number of (3-atomic) solvent molecules: 1891
#
# Processing topology
# Replacing 1 solute molecules in topology file (topol.top)  by 1 NA and 0 CL ions.
#
# Back Off! I just backed up topol.top to ./#topol.top.2#
# Using random seed 1602190782.
# Replacing solvent molecule 1238 (atom 3900) with NA
#
#
# GROMACS reminds you: "Everybody's Good Enough For Some Change" (LIVE)

# %%
# !gmx grompp -f minim.mdp -c helix_solv_ions.gro -p topol.top -o em.tpr
# Out:
#                       :-) GROMACS - gmx grompp, 2024.1 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/hamajun/study/4_sem/inf/helices/test_unstable
# Command line:
#   gmx grompp -f minim.mdp -c helix_solv_ions.gro -p topol.top -o em.tpr
#
# Ignoring obsolete mdp entry 'ns_type'
#
# NOTE 1 [file minim.mdp]:
#   With Verlet lists the optimal nstlist is >= 10, with GPUs >= 20. Note
#   that with the Verlet scheme, nstlist has no effect on the accuracy of
#   your simulation.
#
# Setting the LD random seed to -268451841
#
# Generated 20503 of the 20503 non-bonded parameter combinations
# Generating 1-4 interactions: fudge = 1
#
# Generated 17396 of the 20503 1-4 parameter combinations
#
# Excluding 3 bonded neighbours molecule type 'Protein_chain_X'
#
# Excluding 2 bonded neighbours molecule type 'SOL'
#
# Excluding 1 bonded neighbours molecule type 'NA'
# Analysing residue names:
# There are:    12    Protein residues
# There are:  1890      Water residues
# There are:     1        Ion residues
# Analysing Protein...
# Number of degrees of freedom in T-Coupling group rest is 11898.00
# The integrator does not provide a ensemble temperature, there is no system ensemble temperature
#
# The largest distance between excluded atoms is 0.400 nm between atom 44 and 52
# Calculating fourier grid dimensions for X Y Z
# Using a fourier grid of 40x40x40, spacing 0.109 0.109 0.109
#
# Estimate for the relative computational load of the PME mesh part: 0.29
#
# This run will generate roughly 1 Mb of data
#
# There was 1 NOTE
#
# GROMACS reminds you: "I Am the Psychotherapist. Please, Describe Your Problems." (GNU Emacs)

# %%
# !gmx mdrun -deffnm em
# Out:
#                       :-) GROMACS - gmx mdrun, 2024.1 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/hamajun/study/4_sem/inf/helices/test_unstable
# Command line:
#   gmx mdrun -deffnm em
#
# Reading file em.tpr, VERSION 2024.1 (single precision)
# Using 1 MPI thread
# Using 4 OpenMP threads
#
#
# Steepest Descents:
#    Tolerance (Fmax)   =  5.00000e+02
#    Number of steps    =        50000
#
# writing lowest energy coordinates.
#
# Steepest Descents converged to Fmax < 500 in 602 steps
# Potential Energy  = -9.9971211e+04
# Maximum force     =  4.7931360e+02 on atom 73
# Norm of force     =  2.7709173e+01
#
# GROMACS reminds you: "Like what you do, and then you will do your best." (Katherine Johnson)

# %%
# !printf "Potential\n" | gmx energy -f em.edr -o potential.xvg -xvg none
import pandas as pd
df = pd.read_csv('potential.xvg', sep='\s+', header=None, names=['step','energy'])
df.plot('step')
# Out:
#                       :-) GROMACS - gmx energy, 2024.1 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/hamajun/study/4_sem/inf/helices/gln_all
# Command line:
#   gmx energy -f em.edr -o potential.xvg -xvg none
#
# Opened em.edr as single precision energy file
#
# Select the terms you want from the following list by
# selecting either (part of) the name or the number or a combination.
# End your selection with an empty line or a zero.
# -------------------------------------------------------------------
#   1  Bond             2  U-B              3  Proper-Dih.      4  Improper-Dih.
#   5  CMAP-Dih.        6  LJ-14            7  Coulomb-14       8  LJ-(SR)
#   9  Coulomb-(SR)    10  Coul.-recip.    11  Potential       12  Pressure
#  13  Vir-XX          14  Vir-XY          15  Vir-XZ          16  Vir-YX
#  17  Vir-YY          18  Vir-YZ          19  Vir-ZX          20  Vir-ZY
#  21  Vir-ZZ          22  Pres-XX         23  Pres-XY         24  Pres-XZ
#  25  Pres-YX         26  Pres-YY         27  Pres-YZ         28  Pres-ZX
#  29  Pres-ZY         30  Pres-ZZ         31  #Surf*SurfTen   32  T-rest
#
# Last energy frame read 479 time  606.000
#
# Statistics over 607 steps [ 0.0000 through 606.0000 ps ], 1 data sets
# All statistics are over 480 points (frames)
#
# Energy                      Average   Err.Est.       RMSD  Tot-Drift
# -------------------------------------------------------------------------------
# Potential                  -88337.8       2800    8095.74   -18823.1  (kJ/mol)
#
# GROMACS reminds you: "Never, I said never, compare with experiment" (Magnus Bergh)
# <Axes: xlabel='step'>

# %%
# !gmx grompp -f nvt.mdp -c em.gro -r em.gro -p topol.top -o nvt.tpr
# Out:
#                       :-) GROMACS - gmx grompp, 2024.1 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/hamajun/study/4_sem/inf/helices/test_unstable
# Command line:
#   gmx grompp -f nvt.mdp -c em.gro -r em.gro -p topol.top -o nvt.tpr
#
# Ignoring obsolete mdp entry 'title'
# Ignoring obsolete mdp entry 'ns_type'
# Setting the LD random seed to -1292902405
#
# Generated 20503 of the 20503 non-bonded parameter combinations
# Generating 1-4 interactions: fudge = 1
#
# Generated 17396 of the 20503 1-4 parameter combinations
#
# Excluding 3 bonded neighbours molecule type 'Protein_chain_X'
#
# turning H bonds into constraints...
#
# Excluding 2 bonded neighbours molecule type 'SOL'
#
# turning H bonds into constraints...
#
# Excluding 1 bonded neighbours molecule type 'NA'
#
# turning H bonds into constraints...
#
# Setting gen_seed to -1369735437
#
# Velocities were taken from a Maxwell distribution at 300 K
# Analysing residue names:
# There are:    12    Protein residues
# There are:  1890      Water residues
# There are:     1        Ion residues
# Analysing Protein...
# Number of degrees of freedom in T-Coupling group Protein is 471.88
# Number of degrees of freedom in T-Coupling group non-Protein is 11340.12
#
# The largest distance between excluded atoms is 0.400 nm between atom 161 and 169
#
# Determining Verlet buffer for a tolerance of 0.005 kJ/mol/ps at 300 K
#
# Calculated rlist for 1x1 atom pair-list as 1.036 nm, buffer size 0.036 nm
#
# Set rlist, assuming 4x4 atom pair-list, to 1.000 nm, buffer size 0.000 nm
#
# Note that mdrun will redetermine rlist based on the actual pair-list setup
#
# NOTE 1 [file nvt.mdp]:
#   Removing center of mass motion in the presence of position restraints
#   might cause artifacts. When you are using position restraints to
#   equilibrate a macro-molecule, the artifacts are usually negligible.
#
# Calculating fourier grid dimensions for X Y Z
# Using a fourier grid of 28x28x28, spacing 0.156 0.156 0.156
#
# Estimate for the relative computational load of the PME mesh part: 0.23
#
# This run will generate roughly 14 Mb of data
#
# There was 1 NOTE
#
# GROMACS reminds you: "The greatest shortcoming of the human race is our inability to understand the exponential function." (Albert Bartlett)

# %%
# !gmx mdrun -v -deffnm nvt
# Out:
#                       :-) GROMACS - gmx mdrun, 2024.1 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/hamajun/study/4_sem/inf/helices/test_unstable
# Command line:
#   gmx mdrun -v -deffnm nvt
#
# Reading file nvt.tpr, VERSION 2024.1 (single precision)
# Changing nstlist from 10 to 50, rlist from 1 to 1.118
#
# Using 1 MPI thread
# Using 4 OpenMP threads
#
# starting mdrun 'Good gRace! Old Maple Actually Chews Slate in water'
# 50000 steps,    100.0 ps.
# step 49900, remaining wall clock time:     0 s
# Writing final coordinates.
# step 50000, remaining wall clock time:     0 s
#                Core t (s)   Wall t (s)        (%)
#        Time:      284.029       71.007      400.0
#                  (ns/day)    (hour/ns)
# Performance:      121.680        0.197
#
# GROMACS reminds you: "I never see what has been done; I only see what remains to be done." (Marie Curie)

# %%
# !printf "Temperature\n" | gmx energy -f nvt.edr -o temperature.xvg -xvg none -b 20
import pandas as pd
df = pd.read_csv('temperature.xvg', sep='\s+', header=None, names=['time','temperature'])
df.plot('time')
# Out:
#                       :-) GROMACS - gmx energy, 2024.1 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/hamajun/study/4_sem/inf/helices/gln_all
# Command line:
#   gmx energy -f nvt.edr -o temperature.xvg -xvg none -b 20
#
# Opened nvt.edr as single precision energy file
#
# Select the terms you want from the following list by
# selecting either (part of) the name or the number or a combination.
# End your selection with an empty line or a zero.
# -------------------------------------------------------------------
#   1  Bond             2  U-B              3  Proper-Dih.      4  Improper-Dih.
#   5  CMAP-Dih.        6  LJ-14            7  Coulomb-14       8  LJ-(SR)
#   9  Disper.-corr.   10  Coulomb-(SR)    11  Coul.-recip.    12  Position-Rest.
#  13  Potential       14  Kinetic-En.     15  Total-Energy    16  Conserved-En.
#  17  Temperature     18  Pres.-DC        19  Pressure        20  Constr.-rmsd
#  21  Vir-XX          22  Vir-XY          23  Vir-XZ          24  Vir-YX
#  25  Vir-YY          26  Vir-YZ          27  Vir-ZX          28  Vir-ZY
#  29  Vir-ZZ          30  Pres-XX         31  Pres-XY         32  Pres-XZ
#  33  Pres-YX         34  Pres-YY         35  Pres-YZ         36  Pres-ZX
#  37  Pres-ZY         38  Pres-ZZ         39  #Surf*SurfTen   40  T-Protein
#  41  T-non-Protein                       42  Lamb-Protein
#  43  Lamb-non-Protein
#
# Last energy frame read 100 time  100.000
#
# Statistics over 40001 steps [ 20.0000 through 100.0000 ps ], 1 data sets
# All statistics are over 401 points
#
# Energy                      Average   Err.Est.       RMSD  Tot-Drift
# -------------------------------------------------------------------------------
# Temperature                 300.146       0.24    4.25038  -0.983695  (K)
#
# GROMACS reminds you: "The future still looks good, and you've got time to rectify all the things that you should" (G. Harrison)
# <Axes: xlabel='time'>

# %%
# !gmx grompp -f npt.mdp -c nvt.gro -r nvt.gro -t nvt.cpt -p topol.top -o npt.tpr
# Out:
#                       :-) GROMACS - gmx grompp, 2024.1 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/hamajun/study/4_sem/inf/helices/test_unstable
# Command line:
#   gmx grompp -f npt.mdp -c nvt.gro -r nvt.gro -t nvt.cpt -p topol.top -o npt.tpr
#
# Ignoring obsolete mdp entry 'title'
# Ignoring obsolete mdp entry 'ns_type'
# Setting the LD random seed to 2140127195
#
# Generated 20503 of the 20503 non-bonded parameter combinations
# Generating 1-4 interactions: fudge = 1
#
# Generated 17396 of the 20503 1-4 parameter combinations
#
# Excluding 3 bonded neighbours molecule type 'Protein_chain_X'
#
# turning H bonds into constraints...
#
# Excluding 2 bonded neighbours molecule type 'SOL'
#
# turning H bonds into constraints...
#
# Excluding 1 bonded neighbours molecule type 'NA'
#
# turning H bonds into constraints...
#
# NOTE 1 [file topol.top, line 1837]:
#   You are combining position restraints with Parrinello-Rahman pressure
#   coupling, which can lead to instabilities. If you really want to combine
#   position restraints with pressure coupling, we suggest to use C-rescale
#   pressure coupling instead.
#
#
# The center of mass of the position restraint coord's is  3.371  3.266  1.549
#
# The center of mass of the position restraint coord's is  3.371  3.266  1.549
# Analysing residue names:
# There are:    12    Protein residues
# There are:  1890      Water residues
# There are:     1        Ion residues
# Analysing Protein...
# Number of degrees of freedom in T-Coupling group Protein is 471.88
# Number of degrees of freedom in T-Coupling group non-Protein is 11340.12
#
# The largest distance between excluded atoms is 0.406 nm between atom 161 and 169
#
# Determining Verlet buffer for a tolerance of 0.005 kJ/mol/ps at 300 K
#
# Calculated rlist for 1x1 atom pair-list as 1.036 nm, buffer size 0.036 nm
#
# Set rlist, assuming 4x4 atom pair-list, to 1.000 nm, buffer size 0.000 nm
#
# Note that mdrun will redetermine rlist based on the actual pair-list setup
#
# NOTE 2 [file npt.mdp]:
#   Removing center of mass motion in the presence of position restraints
#   might cause artifacts. When you are using position restraints to
#   equilibrate a macro-molecule, the artifacts are usually negligible.
#
#
# Reading Coordinates, Velocities and Box size from old trajectory
#
# Will read whole trajectory
# Last frame         -1 time  100.000
#
# Using frame at t = 100 ps
#
# Starting time for run is 0 ps
# Calculating fourier grid dimensions for X Y Z
# Using a fourier grid of 28x28x28, spacing 0.156 0.156 0.156
#
# Estimate for the relative computational load of the PME mesh part: 0.23
#
# This run will generate roughly 14 Mb of data
#
# There were 2 NOTEs
#
# GROMACS reminds you: "It's Bicycle Repair Man !" (Monty Python)

# %%
# !gmx mdrun -v -deffnm npt
# Out:
#                       :-) GROMACS - gmx mdrun, 2024.1 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/hamajun/study/4_sem/inf/helices/test_unstable
# Command line:
#   gmx mdrun -v -deffnm npt
#
# Reading file npt.tpr, VERSION 2024.1 (single precision)
# Changing nstlist from 10 to 50, rlist from 1 to 1.117
#
# Using 1 MPI thread
# Using 4 OpenMP threads
#
# starting mdrun 'Good gRace! Old Maple Actually Chews Slate in water'
# 50000 steps,    100.0 ps.
# step 49900, remaining wall clock time:     0 s          , remaining wall clock time:    48 s          , remaining wall clock time:    36 s          , remaining wall clock time:    23 s          , remaining wall clock time:    19 s          37900, remaining wall clock time:    18 s
# Writing final coordinates.
# step 50000, remaining wall clock time:     0 s
#                Core t (s)   Wall t (s)        (%)
#        Time:      305.281       76.320      400.0
#                  (ns/day)    (hour/ns)
# Performance:      113.209        0.212
#
# GROMACS reminds you: "Stay Cool, This is a Robbery" (Pulp Fiction)

# %%
# !printf "Density\n" | gmx energy -f npt.edr -o density.xvg -xvg none
import pandas as pd
df = pd.read_csv('density.xvg', sep='\s+', header=None, names=['time','density'])
df.plot('time')
# Out:
#                       :-) GROMACS - gmx energy, 2024.1 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/hamajun/study/4_sem/inf/helices/gln_all
# Command line:
#   gmx energy -f npt.edr -o density.xvg -xvg none
#
# Opened npt.edr as single precision energy file
#
# Select the terms you want from the following list by
# selecting either (part of) the name or the number or a combination.
# End your selection with an empty line or a zero.
# -------------------------------------------------------------------
#   1  Bond             2  U-B              3  Proper-Dih.      4  Improper-Dih.
#   5  CMAP-Dih.        6  LJ-14            7  Coulomb-14       8  LJ-(SR)
#   9  Disper.-corr.   10  Coulomb-(SR)    11  Coul.-recip.    12  Position-Rest.
#  13  Potential       14  Kinetic-En.     15  Total-Energy    16  Conserved-En.
#  17  Temperature     18  Pres.-DC        19  Pressure        20  Constr.-rmsd
#  21  Box-X           22  Box-Y           23  Box-Z           24  Volume
#  25  Density         26  pV              27  Enthalpy        28  Vir-XX
#  29  Vir-XY          30  Vir-XZ          31  Vir-YX          32  Vir-YY
#  33  Vir-YZ          34  Vir-ZX          35  Vir-ZY          36  Vir-ZZ
#  37  Pres-XX         38  Pres-XY         39  Pres-XZ         40  Pres-YX
#  41  Pres-YY         42  Pres-YZ         43  Pres-ZX         44  Pres-ZY
#  45  Pres-ZZ         46  #Surf*SurfTen   47  Box-Vel-XX      48  Box-Vel-YY
#  49  Box-Vel-ZZ      50  T-Protein       51  T-non-Protein   52  Lamb-Protein
#  53  Lamb-non-Protein
#
# Last energy frame read 100 time  100.000
#
# Statistics over 50001 steps [ 0.0000 through 100.0000 ps ], 1 data sets
# All statistics are over 501 points
#
# Energy                      Average   Err.Est.       RMSD  Tot-Drift
# -------------------------------------------------------------------------------
# Density                      1012.8       0.35    10.0854    1.60487  (kg/m^3)
#
# GROMACS reminds you: "There is only one thing worse than coming home from the lab to a sink full of dirty dishes, and that is not going to the lab at all!" (Chien-Shiung Wu)
# <Axes: xlabel='time'>

# %%
# !gmx grompp -f md.mdp -c npt.gro -t npt.cpt -p topol.top -o md_0_1.tpr
# Out:
#                       :-) GROMACS - gmx grompp, 2024.1 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/hamajun/study/4_sem/inf/helices/test_unstable
# Command line:
#   gmx grompp -f md.mdp -c npt.gro -t npt.cpt -p topol.top -o md_0_1.tpr
#
# Ignoring obsolete mdp entry 'title'
# Ignoring obsolete mdp entry 'ns_type'
# Setting the LD random seed to -134791427
#
# Generated 20503 of the 20503 non-bonded parameter combinations
# Generating 1-4 interactions: fudge = 1
#
# Generated 17396 of the 20503 1-4 parameter combinations
#
# Excluding 3 bonded neighbours molecule type 'Protein_chain_X'
#
# turning H bonds into constraints...
#
# Excluding 2 bonded neighbours molecule type 'SOL'
#
# turning H bonds into constraints...
#
# Excluding 1 bonded neighbours molecule type 'NA'
#
# turning H bonds into constraints...
# Analysing residue names:
# There are:    12    Protein residues
# There are:  1890      Water residues
# There are:     1        Ion residues
# Analysing Protein...
# Number of degrees of freedom in T-Coupling group Protein is 471.88
# Number of degrees of freedom in T-Coupling group non-Protein is 11340.12
#
# The largest distance between excluded atoms is 0.404 nm between atom 44 and 52
#
# Determining Verlet buffer for a tolerance of 0.005 kJ/mol/ps at 300 K
#
# Calculated rlist for 1x1 atom pair-list as 1.036 nm, buffer size 0.036 nm
#
# Set rlist, assuming 4x4 atom pair-list, to 1.000 nm, buffer size 0.000 nm
#
# Note that mdrun will redetermine rlist based on the actual pair-list setup
#
# Reading Coordinates, Velocities and Box size from old trajectory
#
# Will read whole trajectory
# Last frame         -1 time  100.000
#
# Using frame at t = 100 ps
#
# Starting time for run is 0 ps
# Calculating fourier grid dimensions for X Y Z
# Using a fourier grid of 28x28x28, spacing 0.155 0.155 0.155
#
# Estimate for the relative computational load of the PME mesh part: 0.22
#
# This run will generate roughly 13 Mb of data
#
# GROMACS reminds you: "Life need not be easy, provided only that it is not empty." (Lise Meitner)

# %%
# !gmx mdrun -v -deffnm md_0_1
# Out:
#                       :-) GROMACS - gmx mdrun, 2024.1 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/hamajun/study/4_sem/inf/helices/test_unstable
# Command line:
#   gmx mdrun -v -deffnm md_0_1
#
# Reading file md_0_1.tpr, VERSION 2024.1 (single precision)
# Changing nstlist from 10 to 50, rlist from 1 to 1.119
#
# Using 1 MPI thread
# Using 4 OpenMP threads
#
# starting mdrun 'Good gRace! Old Maple Actually Chews Slate in water'
# 2000000 steps,   4000.0 ps.
# step 1999900, remaining wall clock time:     0 s          nish Fri May  3 16:46:55 2024149000, will finish Fri May  3 16:46:55 2024202400, will finish Fri May  3 16:47:32 2024333100, will finish Fri May  3 16:46:30 2024531700, will finish Fri May  3 16:46:08 2024, will finish Fri May  3 16:46:15 20241105600, will finish Fri May  3 16:46:15 2024, will finish Fri May  3 16:46:22 2024, will finish Fri May  3 16:46:23 2024, will finish Fri May  3 16:46:25 2024
# Writing final coordinates.
# step 2000000, remaining wall clock time:     0 s
#                Core t (s)   Wall t (s)        (%)
#        Time:    11346.613     2836.653      400.0
#                          47:16
#                  (ns/day)    (hour/ns)
# Performance:      121.834        0.197
#
# GROMACS reminds you: "Cut It Deep and Cut It Wide" (The Walkabouts)

# %%
# !printf "1\n0\n" | gmx trjconv -s md_0_1.tpr -f md_0_1.xtc -o md_0_1_noPBC.xtc -pbc mol -center
# Out:
#                      :-) GROMACS - gmx trjconv, 2024.1 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/hamajun/study/4_sem/inf/helices/gln_all
# Command line:
#   gmx trjconv -s md_0_1.tpr -f md_0_1.xtc -o md_0_1_noPBC.xtc -pbc mol -center
#
# Note that major changes are planned in future for trjconv, to improve usability and utility.
# Will write xtc: Compressed trajectory (portable xdr format): xtc
# Reading file md_0_1.tpr, VERSION 2024.1 (single precision)
# Reading file md_0_1.tpr, VERSION 2024.1 (single precision)
# Select group for centering
# Group     0 (         System) has  5538 elements
# Group     1 (        Protein) has   207 elements
# Group     2 (      Protein-H) has   109 elements
# Group     3 (        C-alpha) has    12 elements
# Group     4 (       Backbone) has    36 elements
# Group     5 (      MainChain) has    47 elements
# Group     6 (   MainChain+Cb) has    59 elements
# Group     7 (    MainChain+H) has    61 elements
# Group     8 (      SideChain) has   146 elements
# Group     9 (    SideChain-H) has    62 elements
# Group    10 (    Prot-Masses) has   207 elements
# Group    11 (    non-Protein) has  5331 elements
# Group    12 (          Water) has  5331 elements
# Group    13 (            SOL) has  5331 elements
# Group    14 (      non-Water) has   207 elements
# Select a group: Selected 1: 'Protein'
# Select group for output
# Group     0 (         System) has  5538 elements
# Group     1 (        Protein) has   207 elements
# Group     2 (      Protein-H) has   109 elements
# Group     3 (        C-alpha) has    12 elements
# Group     4 (       Backbone) has    36 elements
# Group     5 (      MainChain) has    47 elements
# Group     6 (   MainChain+Cb) has    59 elements
# Group     7 (    MainChain+H) has    61 elements
# Group     8 (      SideChain) has   146 elements
# Group     9 (    SideChain-H) has    62 elements
# Group    10 (    Prot-Masses) has   207 elements
# Group    11 (    non-Protein) has  5331 elements
# Group    12 (          Water) has  5331 elements
# Group    13 (            SOL) has  5331 elements
# Group    14 (      non-Water) has   207 elements
# Select a group: Selected 0: 'System'
# Reading frame       0 time    0.000
# Precision of md_0_1.xtc is 0.001 (nm)
# Using output precision of 0.001 (nm)
#
# Back Off! I just backed up md_0_1_noPBC.xtc to ./#md_0_1_noPBC.xtc.2#
# Last frame        400 time 4000.000    ->  frame    399 time 3990.000       ->  frame      9 time   90.000
#  ->  frame    400 time 4000.000
# Last written: frame    400 time 4000.000
#
#
# GROMACS reminds you: "I Don't Want to Calm Down" (Throwing Muses)

# %%
# !printf "1\n" | gmx mindist -s md_0_1.tpr -f md_0_1_noPBC.xtc -pi -od mindist.xvg -xvg none
# !xmgrace mindist.xvg
# Out:
#                      :-) GROMACS - gmx mindist, 2024.1 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/hamajun/study/4_sem/inf/helices/test_unstable
# Command line:
#   gmx mindist -s md_0_1.tpr -f md_0_1_noPBC.xtc -pi -od mindist.xvg -xvg none
#
# Choose a group for distance calculation
# Reading file md_0_1.tpr, VERSION 2024.1 (single precision)
# Reading file md_0_1.tpr, VERSION 2024.1 (single precision)
# Group     0 (         System) has  5857 elements
# Group     1 (        Protein) has   186 elements
# Group     2 (      Protein-H) has   100 elements
# Group     3 (        C-alpha) has    12 elements
# Group     4 (       Backbone) has    36 elements
# Group     5 (      MainChain) has    47 elements
# Group     6 (   MainChain+Cb) has    58 elements
# Group     7 (    MainChain+H) has    59 elements
# Group     8 (      SideChain) has   127 elements
# Group     9 (    SideChain-H) has    53 elements
# Group    10 (    Prot-Masses) has   186 elements
# Group    11 (    non-Protein) has  5671 elements
# Group    12 (          Water) has  5670 elements
# Group    13 (            SOL) has  5670 elements
# Group    14 (      non-Water) has   187 elements
# Group    15 (            Ion) has     1 elements
# Group    16 ( Water_and_ions) has  5671 elements
# Select a group: Selected 1: 'Protein'
# Last frame        400 time 4000.000
#
# The shortest periodic distance is 1.37783 (nm) at time 3050 (ps),
# between atoms 37 and 185
#
# GROMACS reminds you: "I Should Be the Pimp Of the Year" (Urban Dance Squad)

# %%
# !printf "4\n4\n" | gmx rms -s em.tpr -f md_0_1_noPBC.xtc -o rmsd.xvg -tu ns -xvg none
import pandas as pd
df = pd.read_csv('rmsd.xvg', sep='\s+', header=None, names=['time','RMSD'])
print(df[df.time>0.5].RMSD.mean())
df.plot('time')
# Out:
#                        :-) GROMACS - gmx rms, 2024.1 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/hamajun/study/4_sem/inf/helices/gln_all
# Command line:
#   gmx rms -s em.tpr -f md_0_1_noPBC.xtc -o rmsd.xvg -tu ns -xvg none
#
# Reading file em.tpr, VERSION 2024.1 (single precision)
# Reading file em.tpr, VERSION 2024.1 (single precision)
# Select group for least squares fit
# Group     0 (         System) has  5538 elements
# Group     1 (        Protein) has   207 elements
# Group     2 (      Protein-H) has   109 elements
# Group     3 (        C-alpha) has    12 elements
# Group     4 (       Backbone) has    36 elements
# Group     5 (      MainChain) has    47 elements
# Group     6 (   MainChain+Cb) has    59 elements
# Group     7 (    MainChain+H) has    61 elements
# Group     8 (      SideChain) has   146 elements
# Group     9 (    SideChain-H) has    62 elements
# Group    10 (    Prot-Masses) has   207 elements
# Group    11 (    non-Protein) has  5331 elements
# Group    12 (          Water) has  5331 elements
# Group    13 (            SOL) has  5331 elements
# Group    14 (      non-Water) has   207 elements
# Select a group: Selected 4: 'Backbone'
# Select group for RMSD calculation
# Group     0 (         System) has  5538 elements
# Group     1 (        Protein) has   207 elements
# Group     2 (      Protein-H) has   109 elements
# Group     3 (        C-alpha) has    12 elements
# Group     4 (       Backbone) has    36 elements
# Group     5 (      MainChain) has    47 elements
# Group     6 (   MainChain+Cb) has    59 elements
# Group     7 (    MainChain+H) has    61 elements
# Group     8 (      SideChain) has   146 elements
# Group     9 (    SideChain-H) has    62 elements
# Group    10 (    Prot-Masses) has   207 elements
# Group    11 (    non-Protein) has  5331 elements
# Group    12 (          Water) has  5331 elements
# Group    13 (            SOL) has  5331 elements
# Group    14 (      non-Water) has   207 elements
# Select a group: Selected 4: 'Backbone'
# Reading frame       0 time    0.000
# WARNING: topology has 5538 atoms, whereas trajectory has 207
# Last frame        400 time    4.000
#
# GROMACS reminds you: "I Do It All the Time" (Magnapop)
#
# 0.049086284285714286
# <Axes: xlabel='time'>

# %%
# !echo "1" | gmx gyrate -s md_0_1.tpr -f md_0_1_noPBC.xtc -o gyrate.xvg -xvg none
import pandas as pd
df = pd.read_csv('gyrate.xvg', sep='\s+', header=None, names=['time','Rg'], usecols=[0, 1])
df.plot('time')
# Out:
#                       :-) GROMACS - gmx gyrate, 2024.1 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/hamajun/study/4_sem/inf/helices/gln_all
# Command line:
#   gmx gyrate -s md_0_1.tpr -f md_0_1_noPBC.xtc -o gyrate.xvg -xvg none
#
# Reading file md_0_1.tpr, VERSION 2024.1 (single precision)
# Reading file md_0_1.tpr, VERSION 2024.1 (single precision)
# Last frame        400 time 4000.000
# Analyzed 401 frames, last time 4000.000
#
# GROMACS reminds you: "Perfect is the enemy of good." (Voltaire)
# <Axes: xlabel='time'>

# %%
# !printf "splitch 1\nq\n" | gmx make_ndx -f nvt.tpr -o 
# !printf "1\n1\n"| gmx hbond -f md_0_1_noPBC.xtc -s md_0_1.tpr -n index.ndx -num -xvg none
import pandas as pd
df = pd.read_csv('hbnum.xvg', sep='\s+', header=None, names=['time','H-bonds'], usecols=[0, 1])
df.plot('time')
# Out:
#                      :-) GROMACS - gmx make_ndx, 2024.1 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/hamajun/study/4_sem/inf/helices/gln_all
# Command line:
#   gmx make_ndx -f nvt.tpr -o
#
#
# Reading structure file
# Reading file nvt.tpr, VERSION 2024.1 (single precision)
# Reading file nvt.tpr, VERSION 2024.1 (single precision)
# Going to read 0 old index file(s)
# Analysing residue names:
# There are:    12    Protein residues
# There are:  1777      Water residues
# Analysing Protein...
#
#   0 System              :  5538 atoms
#   1 Protein             :   207 atoms
#   2 Protein-H           :   109 atoms
#   3 C-alpha             :    12 atoms
#   4 Backbone            :    36 atoms
#   5 MainChain           :    47 atoms
#   6 MainChain+Cb        :    59 atoms
#   7 MainChain+H         :    61 atoms
#   8 SideChain           :   146 atoms
#   9 SideChain-H         :    62 atoms
#  10 Prot-Masses         :   207 atoms
#  11 non-Protein         :  5331 atoms
#  12 Water               :  5331 atoms
#  13 SOL                 :  5331 atoms
#  14 non-Water           :   207 atoms
#
#  nr : group      '!': not  'name' nr name   'splitch' nr    Enter: list groups
#  'a': atom       '&': and  'del' nr         'splitres' nr   'l': list residues
#  't': atom type  '|': or   'keep' nr        'splitat' nr    'h': help
#  'r': residue              'res' nr         'chain' char
#  "name": group             'case': case sensitive           'q': save and quit
#  'ri': residue index
#
# >
# Found 1 chain, will not split
# 1:   207 atoms (1 to 207)
#
# >
#
# GROMACS reminds you: "Make the Floor Burn" (2 Unlimited)
#
#                       :-) GROMACS - gmx hbond, 2024.1 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/hamajun/study/4_sem/inf/helices/gln_all
# Command line:
#   gmx hbond -f md_0_1_noPBC.xtc -s md_0_1.tpr -n index.ndx -num -xvg none
#
# Reading file md_0_1.tpr, VERSION 2024.1 (single precision)
# Reading file md_0_1.tpr, VERSION 2024.1 (single precision)
# Checking for overlap in atoms between Protein (207 atoms) and Protein (207 atoms)
# Last frame        400 time 4000.000
# Analyzed 401 frames, last time 4000.000
#
# GROMACS reminds you: "The Universe is Somewhere In Here" (J.G.E.M. Fraaije)
# <Axes: xlabel='time'>

# %%
# !vmd md_0_1.gro md_0_1_noPBC.xtc
# Out:
# /usr/local/lib/vmd/vmd_LINUXAMD64: /lib/x86_64-linux-gnu/libGL.so.1: no version information available (required by /usr/local/lib/vmd/vmd_LINUXAMD64)
# Info) VMD for LINUXAMD64, version 1.9.3 (November 30, 2016)
# Info) http://www.ks.uiuc.edu/Research/vmd/
# Info) Email questions and bug reports to vmd@ks.uiuc.edu
# Info) Please include this reference in published work using VMD:
# Info)    Humphrey, W., Dalke, A. and Schulten, K., `VMD - Visual
# Info)    Molecular Dynamics', J. Molec. Graphics 1996, 14.1, 33-38.
# Info) -------------------------------------------------------------
# Info) Multithreading available, 4 CPUs detected.
# Info)   CPU features: SSE2 AVX AVX2 FMA
# Info) Free system memory: 4584MB (62%)
# Info) No CUDA accelerator devices available.
# Warning) Detected X11 'Composite' extension: if incorrect display occurs
# Warning) try disabling this X server option.  Most OpenGL drivers
# Warning) disable stereoscopic display when 'Composite' is enabled.
# Info) OpenGL renderer: RENOIR (renoir, LLVM 15.0.7, DRM 3.54, 6.5.0-28-generic)
# Info)   Features: STENCIL MSAA(4) MDE CVA MTX NPOT PP PS GLSL(OVFS)
# Info)   Full GLSL rendering mode is available.
# Info)   Textures: 2-D (16384x16384), 3-D (512x512x512), Multitexture (8)
# Info) Detected 22 XInput devices, 2 usable devices:
# Info)   [21] XP-PEN STYLUS, type: 117, classes: 0
# Info)   [23] XP-PEN ERASER, type: 117, classes: 0
# Info) Dynamically loaded 2 plugins in directory:
# Info) /usr/local/lib/vmd/plugins/LINUXAMD64/molfile
# Info) File loading in progress, please wait.
# Info) Using plugin gro for structure file md_0_1.gro
# Info) Using plugin gro for coordinates from file md_0_1.gro
# Info) Determining bond structure from distance search ...
# Info) Finished with coordinate file md_0_1.gro.
# Info) Analyzing structure ...
# Info)    Atoms: 5538
# Info)    Bonds: 3760
# Info)    Angles: 0  Dihedrals: 0  Impropers: 0  Cross-terms: 0
# Info)    Bondtypes: 0  Angletypes: 0  Dihedraltypes: 0  Impropertypes: 0
# Info)    Residues: 1789
# Info)    Waters: 1777
# Info)    Segments: 1
# Info)    Fragments: 1778   Protein: 1   Nucleic: 0
# Info) Using plugin xtc for coordinates from file md_0_1_noPBC.xtc
# Info) Finished with coordinate file md_0_1_noPBC.xtc.
# vmd > numframes: 402
# Generating image frames using renderer: snapshot
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00000.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00001.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00002.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00003.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00004.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00005.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00006.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00007.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00008.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00009.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00010.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00011.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00012.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00013.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00014.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00015.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00016.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00017.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00018.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00019.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00020.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00021.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00022.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00023.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00024.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00025.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00026.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00027.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00028.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00029.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00030.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00031.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00032.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00033.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00034.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00035.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00036.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00037.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00038.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00039.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00040.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00041.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00042.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00043.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00044.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00045.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00046.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00047.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00048.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00049.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00050.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00051.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00052.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00053.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00054.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00055.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00056.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00057.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00058.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00059.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00060.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00061.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00062.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00063.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00064.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00065.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00066.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00067.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00068.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00069.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00070.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00071.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00072.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00073.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00074.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00075.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00076.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00077.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00078.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00079.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00080.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00081.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00082.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00083.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00084.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00085.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00086.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00087.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00088.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00089.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00090.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00091.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00092.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00093.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00094.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00095.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00096.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00097.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00098.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00099.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00100.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00101.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00102.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00103.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00104.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00105.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00106.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00107.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00108.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00109.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00110.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00111.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00112.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00113.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00114.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00115.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00116.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00117.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00118.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00119.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00120.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00121.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00122.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00123.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00124.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00125.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00126.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00127.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00128.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00129.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00130.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00131.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00132.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00133.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00134.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00135.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00136.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00137.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00138.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00139.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00140.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00141.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00142.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00143.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00144.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00145.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00146.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00147.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00148.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00149.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00150.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00151.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00152.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00153.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00154.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00155.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00156.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00157.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00158.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00159.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00160.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00161.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00162.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00163.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00164.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00165.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00166.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00167.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00168.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00169.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00170.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00171.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00172.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00173.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00174.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00175.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00176.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00177.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00178.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00179.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00180.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00181.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00182.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00183.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00184.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00185.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00186.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00187.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00188.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00189.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00190.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00191.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00192.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00193.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00194.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00195.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00196.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00197.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00198.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00199.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00200.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00201.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00202.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00203.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00204.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00205.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00206.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00207.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00208.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00209.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00210.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00211.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00212.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00213.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00214.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00215.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00216.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00217.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00218.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00219.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00220.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00221.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00222.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00223.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00224.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00225.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00226.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00227.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00228.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00229.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00230.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00231.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00232.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00233.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00234.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00235.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00236.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00237.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00238.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00239.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00240.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00241.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00242.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00243.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00244.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00245.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00246.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00247.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00248.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00249.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00250.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00251.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00252.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00253.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00254.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00255.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00256.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00257.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00258.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00259.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00260.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00261.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00262.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00263.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00264.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00265.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00266.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00267.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00268.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00269.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00270.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00271.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00272.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00273.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00274.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00275.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00276.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00277.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00278.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00279.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00280.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00281.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00282.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00283.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00284.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00285.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00286.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00287.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00288.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00289.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00290.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00291.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00292.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00293.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00294.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00295.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00296.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00297.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00298.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00299.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00300.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00301.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00302.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00303.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00304.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00305.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00306.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00307.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00308.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00309.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00310.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00311.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00312.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00313.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00314.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00315.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00316.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00317.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00318.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00319.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00320.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00321.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00322.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00323.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00324.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00325.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00326.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00327.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00328.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00329.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00330.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00331.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00332.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00333.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00334.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00335.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00336.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00337.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00338.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00339.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00340.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00341.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00342.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00343.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00344.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00345.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00346.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00347.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00348.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00349.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00350.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00351.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00352.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00353.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00354.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00355.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00356.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00357.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00358.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00359.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00360.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00361.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00362.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00363.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00364.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00365.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00366.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00367.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00368.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00369.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00370.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00371.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00372.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00373.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00374.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00375.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00376.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00377.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00378.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00379.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00380.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00381.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00382.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00383.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00384.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00385.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00386.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00387.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00388.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00389.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00390.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00391.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00392.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00393.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00394.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00395.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00396.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00397.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00398.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00399.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00400.ppm' ...
# Info) Rendering complete.
# Info) Rendering current scene to '/home/hamajun/study/4_sem/inf/helices/gln_all/traj.00401.ppm' ...
# Info) Rendering complete.
# No frame format conversion necessary, continuing.
# Converting frames to animated GIF format
# convert -delay  3.33 -loop 4 /home/hamajun/study/4_sem/inf/helices/gln_all/traj.*.ppm /home/hamajun/study/4_sem/inf/helices/gln_all/traj.gif
# Cleaning generated data, frames, and encoder parameter files
# Movie generation complete.
# Info) VMD for LINUXAMD64, version 1.9.3 (November 30, 2016)
# Info) Exiting normally.

# %%
import csv
df1 = pd.read_csv('rmsd.xvg', sep='\s+', header=None, names=['time','RMSD'])
df2 = pd.read_csv('gyrate.xvg', sep='\s+', header=None, names=['time','Rg'], usecols=[0, 1])
with open("../table.csv", "a") as f:
    writer = csv.writer(f, delimiter=";")
    writer.writerow([input(), df1[df1.time>0.5].RMSD.mean(), df2[df2.time>0.5].Rg.mean()])
# Out:
#  gln_all
